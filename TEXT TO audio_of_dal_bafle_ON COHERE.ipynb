# %%
pip install cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 70.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import cohere

# Initialize the Cohere client with your API key
cohere_client = cohere.Client('97mJi1LYyaykPh5TwtjRXzqxZ0gLHNFGUUdKK54m')

# Define a function to generate recipes
def generate_recipe(prompt):
    response = cohere_client.generate(
        model='command-xlarge-nightly',  # or use 'command-light-nightly' if you prefer
        prompt=prompt,
        max_tokens=500,  # Increase the number of tokens to ensure a complete recipe
        temperature=0.7,  # Adjust temperature to control creativity
        k=0,
        stop_sequences=["--END--"],
        return_likelihoods='NONE'
    )
    return response.generations[0].text

# English recipe prompt
dal_bafle_prompt_en = """
Generate a complete recipe for Dal Bafle, a traditional Indian dish.

Recipe:
"""

# Hindi recipe prompt
dal_bafle_prompt_hi = """
"दल बाफले" के लिए एक संपूर्ण रेसिपी तैयार करें, जो एक पारंपरिक भारतीय व्यंजन है।

रेसिपी:
"""

# Generate the recipes
recipe_en = generate_recipe(dal_bafle_prompt_en)
recipe_hi = generate_recipe(dal_bafle_prompt_hi)

print("Recipe for Dal Bafle (English):\n", recipe_en)
print("\nRecipe for Dal Bafle (Hindi):\n", recipe_hi)
# Out:
# Recipe for Dal Bafle (English):
#  Dal Bafle: A Traditional Indian Dish
#
# Ingredients:
#
# For the Dal:
# - 1 cup yellow split peas (toor dal)
# - 1/2 cup red lentils (masoor dal)
# - 1 medium onion, finely chopped
# - 2 medium tomatoes, finely chopped
# - 2 green chilies, slit lengthwise
# - 1/2 inch ginger, grated
# - 4 cloves garlic, crushed
# - 1/2 teaspoon turmeric powder
# - 1 teaspoon red chili powder
# - 1 teaspoon coriander powder
# - 1/2 teaspoon cumin powder
# - 1/2 teaspoon garam masala
# - 1/2 teaspoon mustard seeds
# - 1/2 teaspoon cumin seeds
# - A few curry leaves
# - 2 tablespoons chopped coriander leaves for garnishing
# - Salt to taste
# - 1 tablespoon ghee or clarified butter
# - 2 cups water
#
# For the Bafle:
# - 2 cups wheat flour
# - 1/2 cup refined flour (maida)
# - 1/2 teaspoon baking powder
# - 1/2 teaspoon ajwain (carom seeds)
# - Salt to taste
# - Water as required
# - Ghee or oil for deep frying
#
# Instructions:
#
# For the Dal:
# ...

# %%
pip install cohere gtts

# %%
import cohere
from gtts import gTTS
import os

# Initialize the Cohere client with your API key
cohere_client = cohere.Client('97mJi1LYyaykPh5TwtjRXzqxZ0gLHNFGUUdKK54m')

# Define a function to generate recipes
def generate_recipe(prompt):
    response = cohere_client.generate(
        model='command-xlarge-nightly',  # or use 'command-light-nightly' if you prefer
        prompt=prompt,
        max_tokens=500,  # Increase the number of tokens to ensure a complete recipe
        temperature=0.7,  # Adjust temperature to control creativity
        k=0,
        stop_sequences=["--END--"],
        return_likelihoods='NONE'
    )
    return response.generations[0].text

# English recipe prompt
dal_bafle_prompt_en = """
Generate a complete recipe for Dal Bafle, a traditional Indian dish.

Recipe:
"""

# Hindi recipe prompt
dal_bafle_prompt_hi = """
"दल बाफले" के लिए एक संपूर्ण रेसिपी तैयार करें, जो एक पारंपरिक भारतीय व्यंजन है।

रेसिपी:
"""

# Generate the recipes
recipe_en = generate_recipe(dal_bafle_prompt_en)
recipe_hi = generate_recipe(dal_bafle_prompt_hi)

print("Recipe for Dal Bafle (English):\n", recipe_en)
print("\nRecipe for Dal Bafle (Hindi):\n", recipe_hi)

# Convert the English recipe to audio
tts_en = gTTS(text=recipe_en, lang='en')
tts_en.save("dal_bafle_recipe_en.mp3")

# Convert the Hindi recipe to audio
tts_hi = gTTS(text=recipe_hi, lang='hi')
tts_hi.save("dal_bafle_recipe_hi.mp3")

print("Audio files have been saved as dal_bafle_recipe_en.mp3 and dal_bafle_recipe_hi.mp3")
# Out:
# Recipe for Dal Bafle (English):
#  Dal Bafle: A Traditional Indian Dish
#
# Ingredients:
#
# For the Dal:
# - 1 cup yellow split peas (toor dal)
# - 1/2 cup red lentils (masoor dal)
# - 1 medium onion, finely chopped
# - 2 medium tomatoes, finely chopped
# - 2 green chilies, slit lengthwise
# - 1/2 inch ginger, grated
# - 4 cloves garlic, crushed
# - 1/2 teaspoon turmeric powder
# - 1 teaspoon red chili powder
# - 1 teaspoon coriander powder
# - 1/2 teaspoon cumin powder
# - 1/2 teaspoon garam masala
# - 1 tablespoon ghee (clarified butter)
# - Salt to taste
# - Fresh coriander leaves for garnishing
#
# For the Bafle:
# - 2 cups wheat flour
# - 1/2 cup all-purpose flour
# - 1/2 teaspoon baking powder
# - 1/2 teaspoon salt
# - Water, as required
# - Ghee for brushing
#
# Instructions:
#
# For the Dal:
#
# 1. Combine the yellow split peas and red lentils in a bowl, wash and soak them in water for 30 minutes. Drain and set aside.
#
# ...
